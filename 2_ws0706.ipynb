# %% [markdown]
# <a href="https://colab.research.google.com/github/ginttone/test_visuallization/blob/master/2_ws0706.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [kaggle data](https://www.kaggle.com/vikrishnan/boston-house-prices?select=housing.csv)
# * 정보단계
#
# 데이터 fill, replace
#
# 연속형 컬럼만 선택
#
# * 교육단계
#
# standard scaler
#
# model learning
#
#
# * 서비스단계
#
# pickle
#
# 가상 데이터 생성
#
# apply prediction

# %% [markdown]
# 함유량
# 데이터베이스의 각 레코드는 보스턴 교외 또는 마을을 설명합니다. 데이터는 1970 년 Boston Standard Metropolitan Statistical Area (SMSA)에서 가져온 것입니다. 속성은 다음과 같이 정의됩니다 (UCI Machine Learning Repository1에서 가져옴) :
#
# CRIM : 1 인당 도시 별 범죄율
#
# ZN : 25,000 평방 피트 이상의 부지에 구역화 된 주거용 토지의 비율.
#
# INDUS : 도시 당 비 소매 사업 에이커의 비율
#
# CHAS : Charles River 더미 변수 (유도가 강 경계면 = 1, 그렇지 않으면 0)
#
# NOX : 산화 질소 농도 (1000
# 만분 율 ) 1https : //archive.ics.uci.edu/ml/datasets/Housing
# 123
# 20.2. 데이터 세트로드 124
#
# RM : 주거 당 평균 방 수
#
# AGE : 1940 년 이전에 지어진 소유주 소유 유닛의 비율
#
# DIS : 5 개 보스턴 고용 센터까지의 가중 거리
#
# RAD : 방사형 고속도로 접근성 지수
#
# TAX : $ 10,000 당 전체 가치 재산 세율
#
# PTRATIO : 도시 별 학생-교사 비율 12. B : 1000 (Bk−0.63) 2 여기서 Bk는 도시 13의 흑인 비율입니다.
#
# LSTAT : 인구의 낮은 지위 %
#
# MEDV : 소유주가 거주하는 주택의 중앙값 ($ 1000)
# 입력 속성에 단위가 혼합되어 있음을 알 수 있습니다.
#
#
# CRIM,ZN,INDUS,CHAS,NOX,RM ,AGE,DIS,RAD,TAX,PTRATIO,LSTAT,MEDV
#
# '''
# import pandas as pd
# pd.read_csv('./housing.csv', sep=' ', header=None, error_bad_lines=False)
# '''

# %% [markdown]
# ## data loading

# %%
# !ls -l ./Boston.csv
# Out:
# -rw-r--r-- 1 root root 37658 Jul  6 05:13 ./Boston.csv

# %%
import pandas as pd
df = pd.read_csv('./Boston.csv', header=None, index_col = 0 )
df.columns =['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','black','lstat','medv']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 507 entries, nan to 506.0
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     507 non-null    object
#  1   zn       507 non-null    object
#  2   indus    507 non-null    object
#  3   chas     507 non-null    object
#  4   nox      507 non-null    object
#  5   rm       507 non-null    object
#  6   age      507 non-null    object
#  7   dis      507 non-null    object
#  8   rad      507 non-null    object
#  9   tax      507 non-null    object
#  10  ptratio  507 non-null    object
#  11  black    507 non-null    object
#  12  lstat    507 non-null    object
#  13  medv     507 non-null    object
# dtypes: object(14)
# memory usage: 59.4+ KB

# %%
df[['crim','zn']].describe(include='all')
# Out:
#            crim   zn
# count       507  507
# unique      505   27
# top     14.3337    0
# freq          2  372

# %%
df['crim'].value_counts()
# Out:
# 14.3337    2
# 0.01501    2
# 15.288     1
# 0.08308    1
# 0.08244    1
#           ..
# 0.26938    1
# 5.44114    1
# 0.07503    1
# 0.13058    1
# 0.22969    1
# Name: crim, Length: 505, dtype: int64

# %% [markdown]
# 1.   연속형:
#
# 2.   분류형:

# %%
df['age'].value_counts()
# Out:
# 100     43
# 96       4
# 98.2     4
# 98.8     4
# 87.9     4
#         ..
# 78.3     1
# 68.7     1
# 36.1     1
# 8.9      1
# 15.7     1
# Name: age, Length: 357, dtype: int64

# %%
df['age'].unique()
# Out:
# array(['age', '65.2', '78.9', '61.1', '45.8', '54.2', '58.7', '66.6',
#        '96.1', '100', '85.9', '94.3', '82.9', '39', '61.8', '84.5',
#        '56.5', '29.3', '81.7', '36.6', '69.5', '98.1', '89.2', '91.7',
#        '94.1', '85.7', '90.3', '88.8', '94.4', '87.3', '82', '95', '96.9',
#        '68.2', '61.4', '41.5', '30.2', '21.8', '15.8', '2.9', '6.6',
#        '6.5', '40', '33.8', '33.3', '85.5', '95.3', '62', '45.7', '63',
#        '21.1', '21.4', '47.6', '21.9', '35.7', '40.5', '29.2', '47.2',
#        '66.2', '93.4', '67.8', '43.4', '59.5', '17.8', '31.1', '36.8',
#        '33', '17.5', '7.8', '6.2', '6', '45', '74.5', '53.7', '33.5',
#        '70.4', '32.2', '46.7', '48', '56.1', '45.1', '56.8', '86.3',
#        '63.1', '66.1', '73.9', '53.6', '28.9', '77.3', '57.8', '69.6',
#        '76', '36.9', '62.5', '79.9', '71.3', '85.4', '87.4', '90', '96.7',
#        '91.9', '85.2', '97.1', '91.2', '54.4', '81.6', '92.9', '95.4',
# ...

# %%
df_age = df['age'].replace(to_replace='?',value=None,inplace=False)
df_age.unique()
# Out:
# array(['age', '65.2', '78.9', '61.1', '45.8', '54.2', '58.7', '66.6',
#        '96.1', '100', '85.9', '94.3', '82.9', '39', '61.8', '84.5',
#        '56.5', '29.3', '81.7', '36.6', '69.5', '98.1', '89.2', '91.7',
#        '94.1', '85.7', '90.3', '88.8', '94.4', '87.3', '82', '95', '96.9',
#        '68.2', '61.4', '41.5', '30.2', '21.8', '15.8', '2.9', '6.6',
#        '6.5', '40', '33.8', '33.3', '85.5', '95.3', '62', '45.7', '63',
#        '21.1', '21.4', '47.6', '21.9', '35.7', '40.5', '29.2', '47.2',
#        '66.2', '93.4', '67.8', '43.4', '59.5', '17.8', '31.1', '36.8',
#        '33', '17.5', '7.8', '6.2', '6', '45', '74.5', '53.7', '33.5',
#        '70.4', '32.2', '46.7', '48', '56.1', '45.1', '56.8', '86.3',
#        '63.1', '66.1', '73.9', '53.6', '28.9', '77.3', '57.8', '69.6',
#        '76', '36.9', '62.5', '79.9', '71.3', '85.4', '87.4', '90', '96.7',
#        '91.9', '85.2', '97.1', '91.2', '54.4', '81.6', '92.9', '95.4',
# ...
